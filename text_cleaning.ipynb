# %% [markdown]
# <a href="https://colab.research.google.com/github/xedinseu/text_cleaning/blob/main/text_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Отдельно хочу отметить, что до начала обучения (но после пилотной пробы сети) я предподготовил изображения - высота у многих изображений не соответствовала максимальной, и сверху и снизу таких изображений был добавлен серый фон чтобы добить высоту до 420 пикселей

# %%
# инфа по карте коллаба
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install -q gputil
# !pip install -q psutil
# !pip install -q humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
process = psutil.Process(os.getpid())
print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
print("GPU Model: ", gpu.name)
# Out:
#   Building wheel for gputil (setup.py) ... done
# Gen RAM Free: 12.8 GB  | Proc size: 118.2 MB
# GPU RAM Free: 16280MB | Used: 0MB | Util   0% | Total 16280MB
# GPU Model:  Tesla P100-PCIE-16GB

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, concatenate, Dense, Dropout, BatchNormalization, Conv2D, Conv2DTranspose, MaxPooling2D, Flatten,Reshape
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.preprocessing import image
import tensorflow as tf

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import os
import time
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
images_dir = '/content/drive/MyDrive/Базы/text_cleaning/' # зададим имя папки в которой находятся данные
img_height = 424 # зададим высоту изображений
img_width = 544 # зададим ширину избражений

# %%
def plotImages(xTrain, pred, shape=(img_height, img_width)): # создадим функцию для вывода изображений как картинок
  n = 7  # количество картинок, которые хотим показать
  plt.figure(figsize=(28, 7)) # указываем размеры фигуры
  for i in range(n): # для каждой картинки из n(7)
      index = i
      # Показываем картинки из тестового набора
      ax = plt.subplot(2, n, i + 1) # выведем область рисования Axes
      plt.imshow(xTrain[index].reshape(shape)) # отрисуем правильные картинки в размере 112*80      
      plt.gray() # выведем в черно-белом цвете
      ax.get_xaxis().set_visible(False) # скрываем вывод координатной оси x
      ax.get_yaxis().set_visible(False) # скрываем вывод координатной оси y

      # Показываем восстановленные картинки
      ax = plt.subplot(2, n, i + 1 + n) # выведем область рисования Axes 
      plt.imshow(pred[index].reshape(shape)) # отрисуем обработанные сеткой картинки в размере 112*80     
      plt.gray() # выведем в черно-белом цвете
      ax.get_xaxis().set_visible(False) # скрываем вывод координатной оси x
      ax.get_yaxis().set_visible(False) # скрываем вывод координатной оси y
  plt.show()

# %%
# функция загрузки изображений, на вход принемает имя папки с изображениями, высоту и ширину к которой будут преобразованы загружаемые изображения
def load_images(images_dir, img_height, img_width): 
  list_images = [] # создаем пустой список в который будем загружать изображения
  for img in os.listdir(images_dir): # получим список изображений и для каждого изображения
  # добавим в список изображение в виде массива, с заданными размерами, в отенках серого
    list_images.append(image.img_to_array(image.load_img(os.path.join(images_dir, img), target_size=(img_height, img_width), color_mode='grayscale')))
  return np.array(list_images) # возвращаем numpy массив загруженных избражений

# %%
cur_time = time.time() 
xTrain = load_images(images_dir+'train_X', img_height, img_width) # загрузим избражения лиц
xTrain = xTrain/255 # отнормируем изображения от 0 до 1
yTrain = load_images(images_dir+'train_Y', img_height, img_width) # загрузим избражения лиц
yTrain = yTrain/255 # отнормируем изображения от 0 до 1
xTest = load_images(images_dir+'test', img_height, img_width) # загрузим избражения лиц
xTest = xTest/255 # отнормируем изображения от 0 до 1

# %%
xTrain.shape
# Out:
# (144, 424, 544, 1)

# %%
xTrain,xVal,yTrain,yVal = train_test_split(xTrain, yTrain, test_size=0.1)

# %%
def denoiseAutoencoder(): # объявляем функцию создания автокодировщика для подавления шума
    img_input = Input((img_height, img_width,1)) # задаём входные размеры

    # Добавляем четыре сверточных слоя, вместо MaxPooling используем strides
    #x1 = Conv2D(32, (3, 3), strides=2, activation='relu', padding='same')(img_input)
    #x1 = Conv2D(64, (3, 3), strides=2, activation='relu', padding='same')(x1)
    x1 = Conv2D(256, (4, 4), strides=2, activation='relu', padding='same')(img_input)
    x1 = Conv2D(128, (4, 4), strides=2, activation='relu', padding='same')(x1)

    x1 = Conv2D(256, (4, 4), activation='relu', padding='same')(x1)
    #x1 = Conv2D(128, (3, 3), activation='relu', padding='same')(x1)
    #x1 = Conv2D(256, (3, 3), activation='relu', padding='same')(x1)

    x1 = Conv2DTranspose(128, (4, 4), strides=2, padding='same')(x1) # разжимаем картинки из 7*5 до 14*10
    x1 = Conv2DTranspose(256, (4, 4), strides=2, padding='same')(x1) # разжимаем картинки из 14*10 до 28*20
    #x1 = Conv2DTranspose(64, (3, 3), strides=2, padding='same')(x1) # разжимаем картинки из 28*20 до 56*40
    #x1 = Conv2DTranspose(32, (3, 3), strides=2, padding='same')(x1) # разжимаем картинки из 56*40 до 112*80

    #x2 = Conv2D(32, (2, 2), strides=2, activation='relu', padding='same')(img_input)
    #x2 = Conv2D(64, (2, 2), strides=2, activation='relu', padding='same')(x2)
    x2 = Conv2D(256, (3, 3), strides=2, activation='relu', padding='same')(x1)
    x2 = Conv2D(128, (3, 3), strides=2, activation='relu', padding='same')(x2)

    x2 = Conv2D(256, (3, 3), activation='relu', padding='same')(x2)
    #x2 = Conv2D(128, (2, 2), activation='relu', padding='same')(x2)
    #x2 = Conv2D(256, (2, 2), activation='relu', padding='same')(x2)

    x2 = Conv2DTranspose(128, (3, 3), strides=2, padding='same')(x2) # разжимаем картинки из 7*5 до 14*10
    x2 = Conv2DTranspose(256, (3, 3), strides=2, padding='same')(x2) # разжимаем картинки из 14*10 до 28*20
    #x2 = Conv2DTranspose(64, (2, 2), strides=2, padding='same')(x2) # разжимаем картинки из 28*20 до 56*40
    #x2 = Conv2DTranspose(32, (2, 2), strides=2, padding='same')(x2) # разжимаем картинки из 56*40 до 112*80

    x = concatenate([x1,x2])
    x = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x) # и пропускаем через финальный слой двумерной свертки

    model = Model(img_input, x) # собрали модель с зашумленной картинкой на вход и с очищенной от шума на выход
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='mse') # компилируем модель также, с выбором оптимайзера и среднеквадратичной ошибки

    return model # функция вернет модель подавления шума

# %%
filename=images_dir + 'log_v2.csv'
history_logger=tf.keras.callbacks.CSVLogger(filename, separator=",", append=False)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.75,patience=15, min_lr=0.000001)
modelDenoise = denoiseAutoencoder()
# Подаем на вход зашумленные картинки, а на выход правильные, исходные картинки, и обучаем
modelDenoise.fit(xTrain, yTrain, epochs=200, batch_size=4, validation_data = (xVal, yVal), callbacks=[reduce_lr,history_logger])
# Out:
# Epoch 1/200
# 33/33 [==============================] - 27s 246ms/step - loss: 0.1128 - val_loss: 0.0883
# Epoch 2/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0759 - val_loss: 0.0766
# Epoch 3/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0739 - val_loss: 0.0786
# Epoch 4/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0727 - val_loss: 0.0729
# Epoch 5/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0698 - val_loss: 0.0721
# Epoch 6/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0666 - val_loss: 0.0686
# Epoch 7/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0638 - val_loss: 0.0677
# Epoch 8/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0619 - val_loss: 0.0657
# Epoch 9/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0601 - val_loss: 0.0645
# Epoch 10/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0594 - val_loss: 0.0636
# Epoch 11/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0590 - val_loss: 0.0628
# Epoch 12/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0574 - val_loss: 0.0618
# Epoch 13/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0566 - val_loss: 0.0612
# Epoch 14/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0562 - val_loss: 0.0612
# Epoch 15/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0574 - val_loss: 0.0610
# Epoch 16/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0573 - val_loss: 0.0628
# Epoch 17/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0547 - val_loss: 0.0604
# Epoch 18/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0539 - val_loss: 0.0617
# Epoch 19/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0546 - val_loss: 0.0603
# Epoch 20/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0537 - val_loss: 0.0650
# Epoch 21/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0538 - val_loss: 0.0604
# Epoch 22/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0532 - val_loss: 0.0590
# Epoch 23/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0531 - val_loss: 0.0596
# Epoch 24/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0525 - val_loss: 0.0590
# Epoch 25/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0528 - val_loss: 0.0607
# Epoch 26/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0522 - val_loss: 0.0592
# Epoch 27/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0517 - val_loss: 0.0607
# Epoch 28/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0522 - val_loss: 0.0585
# Epoch 29/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0517 - val_loss: 0.0585
# Epoch 30/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0519 - val_loss: 0.0586
# Epoch 31/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0520 - val_loss: 0.0585
# Epoch 32/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0516 - val_loss: 0.0614
# Epoch 33/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0528 - val_loss: 0.0581
# Epoch 34/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0511 - val_loss: 0.0585
# Epoch 35/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0510 - val_loss: 0.0582
# Epoch 36/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0513 - val_loss: 0.0587
# Epoch 37/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0512 - val_loss: 0.0580
# Epoch 38/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0508 - val_loss: 0.0578
# Epoch 39/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0506 - val_loss: 0.0584
# Epoch 40/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0514 - val_loss: 0.0584
# Epoch 41/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0515 - val_loss: 0.0583
# Epoch 42/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0507 - val_loss: 0.0597
# Epoch 43/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0508 - val_loss: 0.0580
# Epoch 44/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0507 - val_loss: 0.0579
# Epoch 45/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0502 - val_loss: 0.0579
# Epoch 46/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0504 - val_loss: 0.0578
# Epoch 47/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0509 - val_loss: 0.0575
# Epoch 48/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0502 - val_loss: 0.0580
# Epoch 49/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0498 - val_loss: 0.0577
# Epoch 50/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0500 - val_loss: 0.0576
# Epoch 51/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0497 - val_loss: 0.0574
# Epoch 52/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0495 - val_loss: 0.0579
# Epoch 53/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0506 - val_loss: 0.0581
# Epoch 54/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0505 - val_loss: 0.0579
# Epoch 55/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0502 - val_loss: 0.0581
# Epoch 56/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0503 - val_loss: 0.0574
# Epoch 57/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0499 - val_loss: 0.0572
# Epoch 58/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0500 - val_loss: 0.0582
# Epoch 59/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0499 - val_loss: 0.0571
# Epoch 60/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0496 - val_loss: 0.0572
# Epoch 61/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0497 - val_loss: 0.0579
# Epoch 62/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0507 - val_loss: 0.0572
# Epoch 63/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0498 - val_loss: 0.0574
# Epoch 64/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0495 - val_loss: 0.0569
# Epoch 65/200
# 33/33 [==============================] - 6s 186ms/step - loss: 0.0495 - val_loss: 0.0569
# Epoch 66/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0493 - val_loss: 0.0571
# Epoch 67/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0514 - val_loss: 0.0581
# Epoch 68/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0498 - val_loss: 0.0574
# Epoch 69/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0492 - val_loss: 0.0571
# Epoch 70/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0492 - val_loss: 0.0573
# Epoch 71/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0493 - val_loss: 0.0568
# Epoch 72/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0495 - val_loss: 0.0585
# Epoch 73/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0494 - val_loss: 0.0569
# Epoch 74/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0497 - val_loss: 0.0569
# Epoch 75/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0490 - val_loss: 0.0571
# Epoch 76/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0491 - val_loss: 0.0575
# Epoch 77/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0496 - val_loss: 0.0576
# Epoch 78/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0491 - val_loss: 0.0568
# Epoch 79/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0492 - val_loss: 0.0571
# Epoch 80/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0491 - val_loss: 0.0569
# Epoch 81/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0491 - val_loss: 0.0568
# Epoch 82/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0490 - val_loss: 0.0571
# Epoch 83/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0490 - val_loss: 0.0567
# Epoch 84/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0494 - val_loss: 0.0582
# Epoch 85/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0491 - val_loss: 0.0571
# Epoch 86/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0488 - val_loss: 0.0570
# Epoch 87/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0492 - val_loss: 0.0571
# Epoch 88/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0499 - val_loss: 0.0573
# Epoch 89/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0496 - val_loss: 0.0572
# Epoch 90/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0487 - val_loss: 0.0569
# Epoch 91/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0487 - val_loss: 0.0568
# Epoch 92/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0488 - val_loss: 0.0568
# Epoch 93/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0486 - val_loss: 0.0567
# Epoch 94/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0488 - val_loss: 0.0569
# Epoch 95/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0488 - val_loss: 0.0568
# Epoch 96/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0490 - val_loss: 0.0570
# Epoch 97/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0487 - val_loss: 0.0566
# Epoch 98/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0485 - val_loss: 0.0571
# Epoch 99/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0486 - val_loss: 0.0569
# Epoch 100/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0484 - val_loss: 0.0589
# Epoch 101/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0490 - val_loss: 0.0570
# Epoch 102/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0485 - val_loss: 0.0563
# Epoch 103/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0484 - val_loss: 0.0576
# Epoch 104/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0484 - val_loss: 0.0567
# Epoch 105/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0484 - val_loss: 0.0565
# Epoch 106/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0484 - val_loss: 0.0568
# Epoch 107/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0486 - val_loss: 0.0565
# Epoch 108/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0484 - val_loss: 0.0566
# Epoch 109/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0487 - val_loss: 0.0565
# Epoch 110/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0484 - val_loss: 0.0567
# Epoch 111/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0483 - val_loss: 0.0566
# Epoch 112/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0482 - val_loss: 0.0567
# Epoch 113/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0481 - val_loss: 0.0569
# Epoch 114/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0482 - val_loss: 0.0564
# Epoch 115/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0483 - val_loss: 0.0565
# Epoch 116/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0480 - val_loss: 0.0568
# Epoch 117/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0481 - val_loss: 0.0568
# Epoch 118/200
# 33/33 [==============================] - 6s 190ms/step - loss: 0.0481 - val_loss: 0.0564
# Epoch 119/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0480 - val_loss: 0.0567
# Epoch 120/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0481 - val_loss: 0.0566
# Epoch 121/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0482 - val_loss: 0.0565
# Epoch 122/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0481 - val_loss: 0.0565
# Epoch 123/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0482 - val_loss: 0.0564
# Epoch 124/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0481 - val_loss: 0.0575
# Epoch 125/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0483 - val_loss: 0.0569
# Epoch 126/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0480 - val_loss: 0.0569
# Epoch 127/200
# 33/33 [==============================] - 6s 190ms/step - loss: 0.0480 - val_loss: 0.0567
# Epoch 128/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0479 - val_loss: 0.0563
# Epoch 129/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0480 - val_loss: 0.0565
# Epoch 130/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0479 - val_loss: 0.0566
# Epoch 131/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0480 - val_loss: 0.0565
# Epoch 132/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0479 - val_loss: 0.0564
# Epoch 133/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0478 - val_loss: 0.0565
# Epoch 134/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0478 - val_loss: 0.0568
# Epoch 135/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0479 - val_loss: 0.0567
# Epoch 136/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0480 - val_loss: 0.0564
# Epoch 137/200
# 33/33 [==============================] - 6s 190ms/step - loss: 0.0478 - val_loss: 0.0564
# Epoch 138/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0479 - val_loss: 0.0563
# Epoch 139/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0477 - val_loss: 0.0566
# Epoch 140/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0477 - val_loss: 0.0574
# Epoch 141/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0482 - val_loss: 0.0568
# Epoch 142/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0476 - val_loss: 0.0569
# Epoch 143/200
# 33/33 [==============================] - 6s 190ms/step - loss: 0.0477 - val_loss: 0.0565
# Epoch 144/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0476 - val_loss: 0.0567
# Epoch 145/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0476 - val_loss: 0.0568
# Epoch 146/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0480 - val_loss: 0.0566
# Epoch 147/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0477 - val_loss: 0.0568
# Epoch 148/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0476 - val_loss: 0.0568
# Epoch 149/200
# 33/33 [==============================] - 6s 190ms/step - loss: 0.0475 - val_loss: 0.0564
# Epoch 150/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0477 - val_loss: 0.0565
# Epoch 151/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0475 - val_loss: 0.0564
# Epoch 152/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0477 - val_loss: 0.0571
# Epoch 153/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0477 - val_loss: 0.0567
# Epoch 154/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0477 - val_loss: 0.0564
# Epoch 155/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0476 - val_loss: 0.0563
# Epoch 156/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0476 - val_loss: 0.0565
# Epoch 157/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0476 - val_loss: 0.0565
# Epoch 158/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0475 - val_loss: 0.0569
# Epoch 159/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0476 - val_loss: 0.0566
# Epoch 160/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0476 - val_loss: 0.0565
# Epoch 161/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0479 - val_loss: 0.0565
# Epoch 162/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0477 - val_loss: 0.0565
# Epoch 163/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0475 - val_loss: 0.0565
# Epoch 164/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0475 - val_loss: 0.0566
# Epoch 165/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0476 - val_loss: 0.0569
# Epoch 166/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0476 - val_loss: 0.0564
# Epoch 167/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0475 - val_loss: 0.0565
# Epoch 168/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0474 - val_loss: 0.0566
# Epoch 169/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0474 - val_loss: 0.0567
# Epoch 170/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0474 - val_loss: 0.0567
# Epoch 171/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0475 - val_loss: 0.0564
# Epoch 172/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0475 - val_loss: 0.0567
# Epoch 173/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0475 - val_loss: 0.0564
# Epoch 174/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0474 - val_loss: 0.0568
# Epoch 175/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0474 - val_loss: 0.0566
# Epoch 176/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0475 - val_loss: 0.0563
# Epoch 177/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0474 - val_loss: 0.0566
# Epoch 178/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0475 - val_loss: 0.0568
# Epoch 179/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0474 - val_loss: 0.0565
# Epoch 180/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0473 - val_loss: 0.0569
# Epoch 181/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0474 - val_loss: 0.0565
# Epoch 182/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0473 - val_loss: 0.0565
# Epoch 183/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0474 - val_loss: 0.0564
# Epoch 184/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0473 - val_loss: 0.0565
# Epoch 185/200
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0474 - val_loss: 0.0565
# Epoch 186/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0474 - val_loss: 0.0564
# Epoch 187/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0473 - val_loss: 0.0565
# Epoch 188/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0473 - val_loss: 0.0564
# Epoch 189/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0474 - val_loss: 0.0564
# Epoch 190/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0473 - val_loss: 0.0567
# Epoch 191/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0473 - val_loss: 0.0564
# Epoch 192/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0473 - val_loss: 0.0565
# Epoch 193/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0473 - val_loss: 0.0566
# Epoch 194/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0473 - val_loss: 0.0566
# Epoch 195/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0472 - val_loss: 0.0565
# Epoch 196/200
# 33/33 [==============================] - 6s 186ms/step - loss: 0.0474 - val_loss: 0.0564
# Epoch 197/200
# 33/33 [==============================] - 6s 190ms/step - loss: 0.0473 - val_loss: 0.0567
# Epoch 198/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0473 - val_loss: 0.0564
# Epoch 199/200
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0472 - val_loss: 0.0566
# Epoch 200/200
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0472 - val_loss: 0.0564

# %%
modelDenoise.save(images_dir + 'modelDenoise_v2.h5')

# %%
yTest = modelDenoise.predict(xTest)
plotImages(xTest, yTest) # взглянем как отрабатывает шумоподавление на зашумленных картинках

# %%
modelDenoise.fit(xTrain, yTrain, epochs=100, batch_size=8, validation_data = (xVal, yVal), callbacks=[reduce_lr,history_logger])
# Out:
# Epoch 1/100
# 17/17 [==============================] - 9s 444ms/step - loss: 0.0472 - val_loss: 0.0565
# Epoch 2/100
# 17/17 [==============================] - 6s 354ms/step - loss: 0.0471 - val_loss: 0.0566
# Epoch 3/100
# 17/17 [==============================] - 6s 354ms/step - loss: 0.0472 - val_loss: 0.0565
# Epoch 4/100
# 17/17 [==============================] - 6s 355ms/step - loss: 0.0472 - val_loss: 0.0566
# Epoch 5/100
# 17/17 [==============================] - 6s 353ms/step - loss: 0.0472 - val_loss: 0.0565
# Epoch 6/100
# 17/17 [==============================] - 6s 353ms/step - loss: 0.0472 - val_loss: 0.0565
# Epoch 7/100
# 17/17 [==============================] - 6s 352ms/step - loss: 0.0472 - val_loss: 0.0565
# Epoch 8/100
# 17/17 [==============================] - 6s 353ms/step - loss: 0.0472 - val_loss: 0.0566
# Epoch 9/100
# 17/17 [==============================] - 6s 353ms/step - loss: 0.0472 - val_loss: 0.0567
# Epoch 10/100
# 17/17 [==============================] - 6s 353ms/step - loss: 0.0472 - val_loss: 0.0566
# Epoch 11/100
# 17/17 [==============================] - 6s 354ms/step - loss: 0.0472 - val_loss: 0.0567
# Epoch 12/100
# 17/17 [==============================] - 6s 353ms/step - loss: 0.0472 - val_loss: 0.0567
# Epoch 13/100
# 17/17 [==============================] - 6s 355ms/step - loss: 0.0471 - val_loss: 0.0566
# Epoch 14/100
# 17/17 [==============================] - 6s 354ms/step - loss: 0.0471 - val_loss: 0.0566
# Epoch 15/100
# 17/17 [==============================] - 6s 353ms/step - loss: 0.0472 - val_loss: 0.0565
# Epoch 16/100
# 11/17 [==================>...........] - ETA: 2s - loss: 0.0510
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-8ac0246b2249> in <module>()
# ----> 1 modelDenoise.fit(xTrain, yTrain, epochs=100, batch_size=8, validation_data = (xVal, yVal), callbacks=[reduce_lr,history_logger])
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1187               logs = tmp_logs  # No error, now safe to assign to logs.
#    1188               end_step = step + data_handler.step_increment
# -> 1189               callbacks.on_train_batch_end(end_step, logs)
#    1190               if self.stop_training:
#    1191                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     433     """
#     434     if self._should_call_train_batch_hooks:
# --> 435       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     436
#     437   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     313       self._batch_times.append(batch_time)
#     314
# --> 315     self._call_batch_hook_helper(hook_name, batch, logs)
#     316
#     317     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     351     for callback in self.callbacks:
#     352       hook = getattr(callback, hook_name)
# --> 353       hook(batch, logs)
#     354
#     355     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1026
#    1027   def on_train_batch_end(self, batch, logs=None):
# -> 1028     self._batch_update_progbar(batch, logs)
#    1029
#    1030   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1098     if self.verbose == 1:
#    1099       # Only block async when verbose = 1.
# -> 1100       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1101       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1102
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#     515
# --> 516   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     517
#     518
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     510   def _to_single_numpy_or_python_type(t):
#     511     if isinstance(t, tf.Tensor):
# --> 512       x = t.numpy()
#     513       return x.item() if np.ndim(x) == 0 else x
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1092     """
#    1093     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1096
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1058   def _numpy(self):
#    1059     try:
# -> 1060       return self._numpy_internal()
#    1061     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
yTest = modelDenoise.predict(xTest)
plotImages(xTest, yTest) # взглянем как отрабатывает шумоподавление на зашумленных картинках

# %%
modelDenoise.save(images_dir + 'modelDenoise_v2.h5')
