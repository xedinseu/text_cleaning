# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, concatenate, Dense, Dropout, BatchNormalization, Conv2D, Conv2DTranspose, MaxPooling2D, Flatten,Reshape
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.preprocessing import image
import tensorflow as tf

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import os
import time
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
images_dir = '/content/drive/MyDrive/Базы/text_cleaning/' # зададим имя папки в которой находятся данные
img_height = 424 # зададим высоту изображений
img_width = 544 # зададим ширину избражений

# %%
def plotImages(xTrain, pred, shape=(img_height, img_width)): # создадим функцию для вывода изображений как картинок
  n = 7  # количество картинок, которые хотим показать
  plt.figure(figsize=(28, 7)) # указываем размеры фигуры
  for i in range(n): # для каждой картинки из n(7)
      index = i
      # Показываем картинки из тестового набора
      ax = plt.subplot(2, n, i + 1) # выведем область рисования Axes
      plt.imshow(xTrain[index].reshape(shape)) # отрисуем правильные картинки в размере 112*80      
      plt.gray() # выведем в черно-белом цвете
      ax.get_xaxis().set_visible(False) # скрываем вывод координатной оси x
      ax.get_yaxis().set_visible(False) # скрываем вывод координатной оси y

      # Показываем восстановленные картинки
      ax = plt.subplot(2, n, i + 1 + n) # выведем область рисования Axes 
      plt.imshow(pred[index].reshape(shape)) # отрисуем обработанные сеткой картинки в размере 112*80     
      plt.gray() # выведем в черно-белом цвете
      ax.get_xaxis().set_visible(False) # скрываем вывод координатной оси x
      ax.get_yaxis().set_visible(False) # скрываем вывод координатной оси y
  plt.show()

# %%
# функция загрузки изображений, на вход принемает имя папки с изображениями, высоту и ширину к которой будут преобразованы загружаемые изображения
def load_images(images_dir, img_height, img_width): 
  list_images = [] # создаем пустой список в который будем загружать изображения
  for img in os.listdir(images_dir): # получим список изображений и для каждого изображения
  # добавим в список изображение в виде массива, с заданными размерами, в отенках серого
    list_images.append(image.img_to_array(image.load_img(os.path.join(images_dir, img), target_size=(img_height, img_width), color_mode='grayscale')))
  return np.array(list_images) # возвращаем numpy массив загруженных избражений

# %%
cur_time = time.time() 
xTrain = load_images(images_dir+'train_X', img_height, img_width) # загрузим избражения лиц
xTrain = xTrain/255 # отнормируем изображения от 0 до 1
yTrain = load_images(images_dir+'train_Y', img_height, img_width) # загрузим избражения лиц
yTrain = yTrain/255 # отнормируем изображения от 0 до 1
xTest = load_images(images_dir+'test', img_height, img_width) # загрузим избражения лиц
xTest = xTest/255 # отнормируем изображения от 0 до 1

# %%
xTrain.shape
# Out:
# (144, 424, 544, 1)

# %%
xTrain,xVal,yTrain,yVal = train_test_split(xTrain, yTrain, test_size=0.1)

# %%
def denoiseAutoencoder(): # объявляем функцию создания автокодировщика для подавления шума
    img_input = Input((img_height, img_width,1)) # задаём входные размеры

    # Добавляем четыре сверточных слоя, вместо MaxPooling используем strides
    x1 = Conv2D(32, (3, 3), strides=2, activation='relu', padding='same')(img_input)
    #x1 = Conv2D(64, (3, 3), strides=2, activation='relu', padding='same')(x1)
    x1 = Conv2D(64, (3, 3), strides=2, activation='relu', padding='same')(x1)
    x1 = Conv2D(128, (3, 3), strides=2, activation='relu', padding='same')(x1)

    x1 = Conv2D(128, (3, 3), activation='relu', padding='same')(x1)
    #x1 = Conv2D(64, (3, 3), activation='relu', padding='same')(x1)
    x1 = Conv2D(128, (3, 3), activation='relu', padding='same')(x1)

    x1 = Conv2DTranspose(128, (3, 3), strides=2, padding='same')(x1) # разжимаем картинки из 7*5 до 14*10
    x1 = Conv2DTranspose(64, (3, 3), strides=2, padding='same')(x1) # разжимаем картинки из 14*10 до 28*20
    #x1 = Conv2DTranspose(64, (3, 3), strides=2, padding='same')(x1) # разжимаем картинки из 28*20 до 56*40
    x1 = Conv2DTranspose(32, (3, 3), strides=2, padding='same')(x1) # разжимаем картинки из 56*40 до 112*80

    x2 = Conv2D(32, (2, 2), strides=2, activation='relu', padding='same')(img_input)
    #x2 = Conv2D(64, (2, 2), strides=2, activation='relu', padding='same')(x2)
    x2 = Conv2D(64, (2, 2), strides=2, activation='relu', padding='same')(x2)
    x2 = Conv2D(128, (2, 2), strides=2, activation='relu', padding='same')(x2)

    x2 = Conv2D(128, (2, 2), activation='relu', padding='same')(x2)
    #x2 = Conv2D(64, (2, 2), activation='relu', padding='same')(x2)
    x2 = Conv2D(128, (2, 2), activation='relu', padding='same')(x2)

    x2 = Conv2DTranspose(128, (2, 2), strides=2, padding='same')(x2) # разжимаем картинки из 7*5 до 14*10
    x2 = Conv2DTranspose(64, (2, 2), strides=2, padding='same')(x2) # разжимаем картинки из 14*10 до 28*20
    #x2 = Conv2DTranspose(64, (2, 2), strides=2, padding='same')(x2) # разжимаем картинки из 28*20 до 56*40
    x2 = Conv2DTranspose(32, (2, 2), strides=2, padding='same')(x2) # разжимаем картинки из 56*40 до 112*80

    x = concatenate([x1,x2])
    x = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x) # и пропускаем через финальный слой двумерной свертки

    model = Model(img_input, x) # собрали модель с зашумленной картинкой на вход и с очищенной от шума на выход
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='mse') # компилируем модель также, с выбором оптимайзера и среднеквадратичной ошибки

    return model # функция вернет модель подавления шума

# %%
filename=images_dir + 'log.csv'
history_logger=tf.keras.callbacks.CSVLogger(filename, separator=",", append=False)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1,patience=15, min_lr=0.000001)
modelDenoise = denoiseAutoencoder()
# Подаем на вход зашумленные картинки, а на выход правильные, исходные картинки, и обучаем
modelDenoise.fit(xTrain, yTrain, epochs=200, batch_size=8, validation_data = (xVal, yVal), callbacks=[reduce_lr,history_logger])
# Out:
# Epoch 1/200
# 17/17 [==============================] - 9s 442ms/step - loss: 0.2156 - val_loss: 0.1936
# Epoch 2/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.1238 - val_loss: 0.0853
# Epoch 3/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0817 - val_loss: 0.0884
# Epoch 4/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0823 - val_loss: 0.0883
# Epoch 5/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0821 - val_loss: 0.0878
# Epoch 6/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0809 - val_loss: 0.0845
# Epoch 7/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0755 - val_loss: 0.0777
# Epoch 8/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0722 - val_loss: 0.0761
# Epoch 9/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0708 - val_loss: 0.0748
# Epoch 10/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0694 - val_loss: 0.0725
# Epoch 11/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0678 - val_loss: 0.0699
# Epoch 12/200
# 17/17 [==============================] - 7s 427ms/step - loss: 0.0663 - val_loss: 0.0685
# Epoch 13/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0658 - val_loss: 0.0683
# Epoch 14/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0655 - val_loss: 0.0677
# Epoch 15/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0653 - val_loss: 0.0675
# Epoch 16/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0651 - val_loss: 0.0676
# Epoch 17/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0650 - val_loss: 0.0672
# Epoch 18/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0649 - val_loss: 0.0671
# Epoch 19/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0649 - val_loss: 0.0674
# Epoch 20/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0650 - val_loss: 0.0677
# Epoch 21/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0647 - val_loss: 0.0671
# Epoch 22/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0647 - val_loss: 0.0672
# Epoch 23/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0646 - val_loss: 0.0669
# Epoch 24/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0645 - val_loss: 0.0670
# Epoch 25/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0645 - val_loss: 0.0671
# Epoch 26/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0643 - val_loss: 0.0667
# Epoch 27/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0643 - val_loss: 0.0669
# Epoch 28/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0645 - val_loss: 0.0667
# Epoch 29/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0642 - val_loss: 0.0667
# Epoch 30/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0642 - val_loss: 0.0667
# Epoch 31/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0643 - val_loss: 0.0666
# Epoch 32/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0643 - val_loss: 0.0670
# Epoch 33/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0640 - val_loss: 0.0663
# Epoch 34/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0641 - val_loss: 0.0668
# Epoch 35/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0640 - val_loss: 0.0668
# Epoch 36/200
# 17/17 [==============================] - 7s 427ms/step - loss: 0.0643 - val_loss: 0.0663
# Epoch 37/200
# 17/17 [==============================] - 7s 428ms/step - loss: 0.0640 - val_loss: 0.0663
# Epoch 38/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0639 - val_loss: 0.0668
# Epoch 39/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0639 - val_loss: 0.0667
# Epoch 40/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0639 - val_loss: 0.0667
# Epoch 41/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0638 - val_loss: 0.0660
# Epoch 42/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0639 - val_loss: 0.0662
# Epoch 43/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0637 - val_loss: 0.0661
# Epoch 44/200
# 17/17 [==============================] - 7s 427ms/step - loss: 0.0638 - val_loss: 0.0660
# Epoch 45/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0636 - val_loss: 0.0661
# Epoch 46/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0636 - val_loss: 0.0659
# Epoch 47/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0637 - val_loss: 0.0661
# Epoch 48/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0635 - val_loss: 0.0658
# Epoch 49/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0635 - val_loss: 0.0659
# Epoch 50/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0634 - val_loss: 0.0663
# Epoch 51/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0634 - val_loss: 0.0662
# Epoch 52/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0634 - val_loss: 0.0660
# Epoch 53/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0636 - val_loss: 0.0665
# Epoch 54/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0636 - val_loss: 0.0659
# Epoch 55/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0633 - val_loss: 0.0656
# Epoch 56/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0632 - val_loss: 0.0655
# Epoch 57/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0632 - val_loss: 0.0655
# Epoch 58/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0631 - val_loss: 0.0653
# Epoch 59/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0631 - val_loss: 0.0654
# Epoch 60/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0632 - val_loss: 0.0652
# Epoch 61/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0630 - val_loss: 0.0655
# Epoch 62/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0631 - val_loss: 0.0651
# Epoch 63/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0632 - val_loss: 0.0653
# Epoch 64/200
# 17/17 [==============================] - 7s 421ms/step - loss: 0.0630 - val_loss: 0.0654
# Epoch 65/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0630 - val_loss: 0.0659
# Epoch 66/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0631 - val_loss: 0.0657
# Epoch 67/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0629 - val_loss: 0.0658
# Epoch 68/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0630 - val_loss: 0.0651
# Epoch 69/200
# 17/17 [==============================] - 7s 421ms/step - loss: 0.0631 - val_loss: 0.0652
# Epoch 70/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0629 - val_loss: 0.0651
# Epoch 71/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0629 - val_loss: 0.0653
# Epoch 72/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0629 - val_loss: 0.0649
# Epoch 73/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0629 - val_loss: 0.0648
# Epoch 74/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0628 - val_loss: 0.0651
# Epoch 75/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0629 - val_loss: 0.0649
# Epoch 76/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0629 - val_loss: 0.0655
# Epoch 77/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0628 - val_loss: 0.0649
# Epoch 78/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0628 - val_loss: 0.0647
# Epoch 79/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0627 - val_loss: 0.0646
# Epoch 80/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0627 - val_loss: 0.0646
# Epoch 81/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0627 - val_loss: 0.0647
# Epoch 82/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0627 - val_loss: 0.0655
# Epoch 83/200
# 17/17 [==============================] - 7s 421ms/step - loss: 0.0630 - val_loss: 0.0646
# Epoch 84/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0629 - val_loss: 0.0646
# Epoch 85/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0626 - val_loss: 0.0650
# Epoch 86/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0627 - val_loss: 0.0648
# Epoch 87/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0626 - val_loss: 0.0644
# Epoch 88/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0628 - val_loss: 0.0647
# Epoch 89/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0627 - val_loss: 0.0653
# Epoch 90/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0625 - val_loss: 0.0645
# Epoch 91/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0624 - val_loss: 0.0646
# Epoch 92/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0625 - val_loss: 0.0645
# Epoch 93/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0625 - val_loss: 0.0644
# Epoch 94/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0625 - val_loss: 0.0644
# Epoch 95/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0626 - val_loss: 0.0643
# Epoch 96/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0624 - val_loss: 0.0642
# Epoch 97/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0625 - val_loss: 0.0647
# Epoch 98/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0624 - val_loss: 0.0648
# Epoch 99/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0625 - val_loss: 0.0642
# Epoch 100/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0624 - val_loss: 0.0642
# Epoch 101/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0625 - val_loss: 0.0641
# Epoch 102/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0623 - val_loss: 0.0641
# Epoch 103/200
# 17/17 [==============================] - 7s 421ms/step - loss: 0.0622 - val_loss: 0.0641
# Epoch 104/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0622 - val_loss: 0.0647
# Epoch 105/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0621 - val_loss: 0.0640
# Epoch 106/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0622 - val_loss: 0.0644
# Epoch 107/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0626 - val_loss: 0.0642
# Epoch 108/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0624 - val_loss: 0.0644
# Epoch 109/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0623 - val_loss: 0.0643
# Epoch 110/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0622 - val_loss: 0.0645
# Epoch 111/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.0623 - val_loss: 0.0652
# Epoch 112/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0622 - val_loss: 0.0640
# Epoch 113/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0623 - val_loss: 0.0640
# Epoch 114/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0622 - val_loss: 0.0641
# Epoch 115/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0621 - val_loss: 0.0640
# Epoch 116/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0621 - val_loss: 0.0640
# Epoch 117/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0621 - val_loss: 0.0639
# Epoch 118/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0620 - val_loss: 0.0643
# Epoch 119/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0621 - val_loss: 0.0641
# Epoch 120/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0620 - val_loss: 0.0638
# Epoch 121/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0621 - val_loss: 0.0641
# Epoch 122/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0623 - val_loss: 0.0640
# Epoch 123/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0620 - val_loss: 0.0638
# Epoch 124/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0619 - val_loss: 0.0642
# Epoch 125/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0618 - val_loss: 0.0641
# Epoch 126/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0619 - val_loss: 0.0638
# Epoch 127/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0620 - val_loss: 0.0641
# Epoch 128/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0621 - val_loss: 0.0640
# Epoch 129/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0618 - val_loss: 0.0636
# Epoch 130/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0619 - val_loss: 0.0637
# Epoch 131/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0619 - val_loss: 0.0638
# Epoch 132/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0621 - val_loss: 0.0638
# Epoch 133/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0621 - val_loss: 0.0638
# Epoch 134/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0620 - val_loss: 0.0640
# Epoch 135/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0620 - val_loss: 0.0640
# Epoch 136/200
# 17/17 [==============================] - 7s 421ms/step - loss: 0.0617 - val_loss: 0.0642
# Epoch 137/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0618 - val_loss: 0.0637
# Epoch 138/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0617 - val_loss: 0.0634
# Epoch 139/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0617 - val_loss: 0.0636
# Epoch 140/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0618 - val_loss: 0.0637
# Epoch 141/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0618 - val_loss: 0.0638
# Epoch 142/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0616 - val_loss: 0.0638
# Epoch 143/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0616 - val_loss: 0.0642
# Epoch 144/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0617 - val_loss: 0.0640
# Epoch 145/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0618 - val_loss: 0.0635
# Epoch 146/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0616 - val_loss: 0.0636
# Epoch 147/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0616 - val_loss: 0.0637
# Epoch 148/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0616 - val_loss: 0.0636
# Epoch 149/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0615 - val_loss: 0.0632
# Epoch 150/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0617 - val_loss: 0.0636
# Epoch 151/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0616 - val_loss: 0.0632
# Epoch 152/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0616 - val_loss: 0.0632
# Epoch 153/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0615 - val_loss: 0.0633
# Epoch 154/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0616 - val_loss: 0.0631
# Epoch 155/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0615 - val_loss: 0.0633
# Epoch 156/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0614 - val_loss: 0.0631
# Epoch 157/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0617 - val_loss: 0.0632
# Epoch 158/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0615 - val_loss: 0.0631
# Epoch 159/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0615 - val_loss: 0.0633
# Epoch 160/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0614 - val_loss: 0.0635
# Epoch 161/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0616 - val_loss: 0.0632
# Epoch 162/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0616 - val_loss: 0.0633
# Epoch 163/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0616 - val_loss: 0.0634
# Epoch 164/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0614 - val_loss: 0.0633
# Epoch 165/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0614 - val_loss: 0.0634
# Epoch 166/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0614 - val_loss: 0.0633
# Epoch 167/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.0615 - val_loss: 0.0630
# Epoch 168/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0615 - val_loss: 0.0632
# Epoch 169/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0614 - val_loss: 0.0631
# Epoch 170/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0612 - val_loss: 0.0630
# Epoch 171/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0612 - val_loss: 0.0631
# Epoch 172/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0612 - val_loss: 0.0631
# Epoch 173/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0611 - val_loss: 0.0632
# Epoch 174/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0612 - val_loss: 0.0632
# Epoch 175/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0611 - val_loss: 0.0630
# Epoch 176/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0611 - val_loss: 0.0630
# Epoch 177/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0611 - val_loss: 0.0630
# Epoch 178/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0611 - val_loss: 0.0631
# Epoch 179/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0611 - val_loss: 0.0631
# Epoch 180/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0611 - val_loss: 0.0630
# Epoch 181/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0611 - val_loss: 0.0630
# Epoch 182/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0611 - val_loss: 0.0632
# Epoch 183/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0611 - val_loss: 0.0631
# Epoch 184/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0611 - val_loss: 0.0631
# Epoch 185/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0611 - val_loss: 0.0631
# Epoch 186/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0611 - val_loss: 0.0630
# Epoch 187/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.0611 - val_loss: 0.0630
# Epoch 188/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0611 - val_loss: 0.0630
# Epoch 189/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0611 - val_loss: 0.0630
# Epoch 190/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0611 - val_loss: 0.0632
# Epoch 191/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0611 - val_loss: 0.0632
# Epoch 192/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0611 - val_loss: 0.0632
# Epoch 193/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0611 - val_loss: 0.0632
# Epoch 194/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0611 - val_loss: 0.0632
# Epoch 195/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0611 - val_loss: 0.0632
# Epoch 196/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0611 - val_loss: 0.0632
# Epoch 197/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0611 - val_loss: 0.0632
# Epoch 198/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.0611 - val_loss: 0.0631
# Epoch 199/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0611 - val_loss: 0.0631
# Epoch 200/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.0611 - val_loss: 0.0631

# %%
yTest = modelDenoise.predict(xTest)

# %%
plotImages(xTest, yTest) # взглянем как отрабатывает шумоподавление на зашумленных картинках

# %%
plotImages(xTrain, yTrain)
