# %% [markdown]
# <a href="https://colab.research.google.com/github/xedinseu/text_cleaning/blob/main/text_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Отдельно хочу отметить, что до начала обучения (но после пилотной пробы сети) я предподготовил изображения - высота у многих изображений не соответствовала максимальной, и сверху и снизу таких изображений был добавлен белый фон чтобы добить высоту до 420 пикселей

# %%
# инфа по карте коллаба
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install -q gputil
# !pip install -q psutil
# !pip install -q humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
process = psutil.Process(os.getpid())
print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
print("GPU Model: ", gpu.name)
# Out:
#   Building wheel for gputil (setup.py) ... done
# Gen RAM Free: 12.8 GB  | Proc size: 118.5 MB
# GPU RAM Free: 16280MB | Used: 0MB | Util   0% | Total 16280MB
# GPU Model:  Tesla P100-PCIE-16GB

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, concatenate, Dense, Dropout, BatchNormalization, Conv2D, Conv2DTranspose, MaxPooling2D, Flatten,Reshape
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.preprocessing import image
import tensorflow as tf

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import os
import time
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
images_dir = '/content/drive/MyDrive/Базы/text_cleaning/' # зададим имя папки в которой находятся данные
img_height = 424 # зададим высоту изображений
img_width = 544 # зададим ширину избражений

# %%
def plotImages(xTrain, pred, shape=(img_height, img_width)): # создадим функцию для вывода изображений как картинок
  n = 7  # количество картинок, которые хотим показать
  plt.figure(figsize=(28, 7)) # указываем размеры фигуры
  for i in range(n): # для каждой картинки из n(7)
      index = i
      # Показываем картинки из тестового набора
      ax = plt.subplot(2, n, i + 1) # выведем область рисования Axes
      plt.imshow(xTrain[index].reshape(shape)) # отрисуем правильные картинки в размере 112*80      
      plt.gray() # выведем в черно-белом цвете
      ax.get_xaxis().set_visible(False) # скрываем вывод координатной оси x
      ax.get_yaxis().set_visible(False) # скрываем вывод координатной оси y

      # Показываем восстановленные картинки
      ax = plt.subplot(2, n, i + 1 + n) # выведем область рисования Axes 
      plt.imshow(pred[index].reshape(shape)) # отрисуем обработанные сеткой картинки в размере 112*80     
      plt.gray() # выведем в черно-белом цвете
      ax.get_xaxis().set_visible(False) # скрываем вывод координатной оси x
      ax.get_yaxis().set_visible(False) # скрываем вывод координатной оси y
  plt.show()

# %%
# функция загрузки изображений, на вход принемает имя папки с изображениями, высоту и ширину к которой будут преобразованы загружаемые изображения
def load_images(images_dir, img_height, img_width): 
  list_images = [] # создаем пустой список в который будем загружать изображения
  for img in os.listdir(images_dir): # получим список изображений и для каждого изображения
  # добавим в список изображение в виде массива, с заданными размерами, в отенках серого
    list_images.append(image.img_to_array(image.load_img(os.path.join(images_dir, img), target_size=(img_height, img_width), color_mode='grayscale')))
  return np.array(list_images) # возвращаем numpy массив загруженных избражений

# %%
cur_time = time.time() 
xTrain = load_images(images_dir+'train_X', img_height, img_width) # загрузим избражения лиц
xTrain = xTrain/255 # отнормируем изображения от 0 до 1
yTrain = load_images(images_dir+'train_Y', img_height, img_width) # загрузим избражения лиц
yTrain = yTrain/255 # отнормируем изображения от 0 до 1
xTest = load_images(images_dir+'test', img_height, img_width) # загрузим избражения лиц
xTest = xTest/255 # отнормируем изображения от 0 до 1

# %%
plt.imshow(xTrain[10][:,:,0])

# %%
xTrain.shape
# Out:
# (144, 424, 544, 1)

# %%
xTrain,xVal,yTrain,yVal = train_test_split(xTrain, yTrain, test_size=0.1)

# %%
def denoiseAutoencoder(): # объявляем функцию создания автокодировщика для подавления шума
    img_input = Input((img_height, img_width,1)) # задаём входные размеры

    x1 = Conv2D(256, (4, 4), strides=2, activation='relu', padding='same')(img_input)
    x1 = Conv2D(128, (4, 4), strides=2, activation='relu', padding='same')(x1)

    x1 = Conv2D(256, (4, 4), activation='relu', padding='same')(x1)

    x1 = Conv2DTranspose(128, (4, 4), strides=2, padding='same')(x1)
    x1 = Conv2DTranspose(256, (4, 4), strides=2, padding='same')(x1)

    x2 = Conv2D(256, (3, 3), strides=2, activation='relu', padding='same')(img_input)
    x2 = Conv2D(128, (3, 3), strides=2, activation='relu', padding='same')(x2)

    x2 = Conv2D(256, (3, 3), activation='relu', padding='same')(x2)

    x2 = Conv2DTranspose(128, (3, 3), strides=2, padding='same')(x2)
    x2 = Conv2DTranspose(256, (3, 3), strides=2, padding='same')(x2) 

    x = concatenate([x1,x2])
    x = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x) # и пропускаем через финальный слой двумерной свертки

    model = Model(img_input, x) # собрали модель с зашумленной картинкой на вход и с очищенной от шума на выход
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='mse') # компилируем модель также, с выбором оптимайзера и среднеквадратичной ошибки

    return model # функция вернет модель подавления шума

# %%
filename=images_dir + 'log_v3.csv'
history_logger=tf.keras.callbacks.CSVLogger(filename, separator=",", append=False)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.75,patience=15, min_lr=0.000001)
modelDenoise = denoiseAutoencoder()
# Подаем на вход зашумленные картинки, а на выход правильные, исходные картинки, и обучаем
modelDenoise.fit(xTrain, yTrain, epochs=200, batch_size=4, validation_data = (xVal, yVal), callbacks=[reduce_lr,history_logger])
# Out:
# Epoch 1/200
# 33/33 [==============================] - 40s 578ms/step - loss: 0.1075 - val_loss: 0.0699
# Epoch 2/200
# 33/33 [==============================] - 16s 477ms/step - loss: 0.0733 - val_loss: 0.0699
# Epoch 3/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0733 - val_loss: 0.0699
# Epoch 4/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0733 - val_loss: 0.0699
# Epoch 5/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0732 - val_loss: 0.0699
# Epoch 6/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0732 - val_loss: 0.0699
# Epoch 7/200
# 33/33 [==============================] - 16s 480ms/step - loss: 0.0732 - val_loss: 0.0697
# Epoch 8/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0667 - val_loss: 0.0587
# Epoch 9/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0580 - val_loss: 0.0553
# Epoch 10/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0536 - val_loss: 0.0523
# Epoch 11/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0484 - val_loss: 0.0487
# Epoch 12/200
# 33/33 [==============================] - 16s 480ms/step - loss: 0.0448 - val_loss: 0.0466
# Epoch 13/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0429 - val_loss: 0.0457
# Epoch 14/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0418 - val_loss: 0.0451
# Epoch 15/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0406 - val_loss: 0.0454
# Epoch 16/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0396 - val_loss: 0.0443
# Epoch 17/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0388 - val_loss: 0.0510
# Epoch 18/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0386 - val_loss: 0.0437
# Epoch 19/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0373 - val_loss: 0.0467
# Epoch 20/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0381 - val_loss: 0.0444
# Epoch 21/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0369 - val_loss: 0.0436
# Epoch 22/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0366 - val_loss: 0.0427
# Epoch 23/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0363 - val_loss: 0.0436
# Epoch 24/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0360 - val_loss: 0.0424
# Epoch 25/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0363 - val_loss: 0.0427
# Epoch 26/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0358 - val_loss: 0.0429
# Epoch 27/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0357 - val_loss: 0.0426
# Epoch 28/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0360 - val_loss: 0.0424
# Epoch 29/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0350 - val_loss: 0.0421
# Epoch 30/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0350 - val_loss: 0.0420
# Epoch 31/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0355 - val_loss: 0.0416
# Epoch 32/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0350 - val_loss: 0.0424
# Epoch 33/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0345 - val_loss: 0.0420
# Epoch 34/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0346 - val_loss: 0.0421
# Epoch 35/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0349 - val_loss: 0.0416
# Epoch 36/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0341 - val_loss: 0.0416
# Epoch 37/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0340 - val_loss: 0.0416
# Epoch 38/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0343 - val_loss: 0.0419
# Epoch 39/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0341 - val_loss: 0.0413
# Epoch 40/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0353 - val_loss: 0.0423
# Epoch 41/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0344 - val_loss: 0.0408
# Epoch 42/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0339 - val_loss: 0.0417
# Epoch 43/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0337 - val_loss: 0.0412
# Epoch 44/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0338 - val_loss: 0.0412
# Epoch 45/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0343 - val_loss: 0.0437
# Epoch 46/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0337 - val_loss: 0.0410
# Epoch 47/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0342 - val_loss: 0.0420
# Epoch 48/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0338 - val_loss: 0.0415
# Epoch 49/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0337 - val_loss: 0.0423
# Epoch 50/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0346 - val_loss: 0.0423
# Epoch 51/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0335 - val_loss: 0.0414
# Epoch 52/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0334 - val_loss: 0.0419
# Epoch 53/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0334 - val_loss: 0.0410
# Epoch 54/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0337 - val_loss: 0.0420
# Epoch 55/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0344 - val_loss: 0.0412
# Epoch 56/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0335 - val_loss: 0.0409
# Epoch 57/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0331 - val_loss: 0.0412
# Epoch 58/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0332 - val_loss: 0.0410
# Epoch 59/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0330 - val_loss: 0.0407
# Epoch 60/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0332 - val_loss: 0.0409
# Epoch 61/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0330 - val_loss: 0.0406
# Epoch 62/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0339 - val_loss: 0.0405
# Epoch 63/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0331 - val_loss: 0.0405
# Epoch 64/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0333 - val_loss: 0.0409
# Epoch 65/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0330 - val_loss: 0.0411
# Epoch 66/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0331 - val_loss: 0.0406
# Epoch 67/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0331 - val_loss: 0.0409
# Epoch 68/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0331 - val_loss: 0.0407
# Epoch 69/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0330 - val_loss: 0.0407
# Epoch 70/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0331 - val_loss: 0.0410
# Epoch 71/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0332 - val_loss: 0.0405
# Epoch 72/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0331 - val_loss: 0.0408
# Epoch 73/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0328 - val_loss: 0.0406
# Epoch 74/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0329 - val_loss: 0.0406
# Epoch 75/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0329 - val_loss: 0.0405
# Epoch 76/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0328 - val_loss: 0.0407
# Epoch 77/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0328 - val_loss: 0.0411
# Epoch 78/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0327 - val_loss: 0.0407
# Epoch 79/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0327 - val_loss: 0.0407
# Epoch 80/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0328 - val_loss: 0.0403
# Epoch 81/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0330 - val_loss: 0.0408
# Epoch 82/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0326 - val_loss: 0.0401
# Epoch 83/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0328 - val_loss: 0.0402
# Epoch 84/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0328 - val_loss: 0.0403
# Epoch 85/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0326 - val_loss: 0.0407
# Epoch 86/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0330 - val_loss: 0.0406
# Epoch 87/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0325 - val_loss: 0.0406
# Epoch 88/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0326 - val_loss: 0.0400
# Epoch 89/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0328 - val_loss: 0.0404
# Epoch 90/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0326 - val_loss: 0.0408
# Epoch 91/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0328 - val_loss: 0.0403
# Epoch 92/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0330 - val_loss: 0.0406
# Epoch 93/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0328 - val_loss: 0.0404
# Epoch 94/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0325 - val_loss: 0.0407
# Epoch 95/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0326 - val_loss: 0.0405
# Epoch 96/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0327 - val_loss: 0.0401
# Epoch 97/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0328 - val_loss: 0.0407
# Epoch 98/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0327 - val_loss: 0.0405
# Epoch 99/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0326 - val_loss: 0.0401
# Epoch 100/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0326 - val_loss: 0.0400
# Epoch 101/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0325 - val_loss: 0.0403
# Epoch 102/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0325 - val_loss: 0.0400
# Epoch 103/200
# 33/33 [==============================] - 16s 480ms/step - loss: 0.0325 - val_loss: 0.0402
# Epoch 104/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0325 - val_loss: 0.0406
# Epoch 105/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0328 - val_loss: 0.0398
# Epoch 106/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0324 - val_loss: 0.0402
# Epoch 107/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0324 - val_loss: 0.0405
# Epoch 108/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0324 - val_loss: 0.0404
# Epoch 109/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0330 - val_loss: 0.0400
# Epoch 110/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0325 - val_loss: 0.0402
# Epoch 111/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0323 - val_loss: 0.0400
# Epoch 112/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0324 - val_loss: 0.0404
# Epoch 113/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0324 - val_loss: 0.0403
# Epoch 114/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0326 - val_loss: 0.0402
# Epoch 115/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0324 - val_loss: 0.0402
# Epoch 116/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0325 - val_loss: 0.0403
# Epoch 117/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0324 - val_loss: 0.0403
# Epoch 118/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0323 - val_loss: 0.0406
# Epoch 119/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0324 - val_loss: 0.0402
# Epoch 120/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0325 - val_loss: 0.0401
# Epoch 121/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0324 - val_loss: 0.0401
# Epoch 122/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0325 - val_loss: 0.0406
# Epoch 123/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0323 - val_loss: 0.0403
# Epoch 124/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0323 - val_loss: 0.0402
# Epoch 125/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0323 - val_loss: 0.0400
# Epoch 126/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0326 - val_loss: 0.0404
# Epoch 127/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0323 - val_loss: 0.0403
# Epoch 128/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0323 - val_loss: 0.0401
# Epoch 129/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0323 - val_loss: 0.0403
# Epoch 130/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0324 - val_loss: 0.0403
# Epoch 131/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0323 - val_loss: 0.0403
# Epoch 132/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0324 - val_loss: 0.0404
# Epoch 133/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0323 - val_loss: 0.0402
# Epoch 134/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0322 - val_loss: 0.0402
# Epoch 135/200
# 33/33 [==============================] - 16s 480ms/step - loss: 0.0322 - val_loss: 0.0403
# Epoch 136/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0323 - val_loss: 0.0403
# Epoch 137/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0323 - val_loss: 0.0402
# Epoch 138/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0322 - val_loss: 0.0401
# Epoch 139/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0322 - val_loss: 0.0401
# Epoch 140/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0322 - val_loss: 0.0402
# Epoch 141/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0322 - val_loss: 0.0401
# Epoch 142/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0402
# Epoch 143/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0322 - val_loss: 0.0402
# Epoch 144/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0399
# Epoch 145/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0322 - val_loss: 0.0402
# Epoch 146/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0322 - val_loss: 0.0398
# Epoch 147/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0322 - val_loss: 0.0400
# Epoch 148/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0400
# Epoch 149/200
# 33/33 [==============================] - 16s 480ms/step - loss: 0.0322 - val_loss: 0.0402
# Epoch 150/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0322 - val_loss: 0.0402
# Epoch 151/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0323 - val_loss: 0.0402
# Epoch 152/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0322 - val_loss: 0.0399
# Epoch 153/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0322 - val_loss: 0.0404
# Epoch 154/200
# 33/33 [==============================] - 16s 480ms/step - loss: 0.0322 - val_loss: 0.0400
# Epoch 155/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0322 - val_loss: 0.0398
# Epoch 156/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0401
# Epoch 157/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0322 - val_loss: 0.0401
# Epoch 158/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0324 - val_loss: 0.0401
# Epoch 159/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0322 - val_loss: 0.0400
# Epoch 160/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0401
# Epoch 161/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0400
# Epoch 162/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0322 - val_loss: 0.0399
# Epoch 163/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0321 - val_loss: 0.0401
# Epoch 164/200
# 33/33 [==============================] - 16s 480ms/step - loss: 0.0321 - val_loss: 0.0401
# Epoch 165/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0322 - val_loss: 0.0400
# Epoch 166/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0399
# Epoch 167/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0322 - val_loss: 0.0402
# Epoch 168/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0322 - val_loss: 0.0399
# Epoch 169/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0400
# Epoch 170/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0401
# Epoch 171/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0321 - val_loss: 0.0401
# Epoch 172/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0321 - val_loss: 0.0401
# Epoch 173/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0322 - val_loss: 0.0401
# Epoch 174/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0322 - val_loss: 0.0402
# Epoch 175/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0399
# Epoch 176/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0400
# Epoch 177/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0399
# Epoch 178/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0321 - val_loss: 0.0400
# Epoch 179/200
# 33/33 [==============================] - 16s 480ms/step - loss: 0.0322 - val_loss: 0.0402
# Epoch 180/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0401
# Epoch 181/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0320 - val_loss: 0.0399
# Epoch 182/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0400
# Epoch 183/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0400
# Epoch 184/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0320 - val_loss: 0.0400
# Epoch 185/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0320 - val_loss: 0.0399
# Epoch 186/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0321 - val_loss: 0.0400
# Epoch 187/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0400
# Epoch 188/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0320 - val_loss: 0.0399
# Epoch 189/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0321 - val_loss: 0.0401
# Epoch 190/200
# 33/33 [==============================] - 16s 480ms/step - loss: 0.0321 - val_loss: 0.0400
# Epoch 191/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0320 - val_loss: 0.0398
# Epoch 192/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0401
# Epoch 193/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0321 - val_loss: 0.0400
# Epoch 194/200
# 33/33 [==============================] - 16s 478ms/step - loss: 0.0320 - val_loss: 0.0400
# Epoch 195/200
# 33/33 [==============================] - 16s 480ms/step - loss: 0.0321 - val_loss: 0.0401
# Epoch 196/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0320 - val_loss: 0.0400
# Epoch 197/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0320 - val_loss: 0.0401
# Epoch 198/200
# 33/33 [==============================] - 16s 480ms/step - loss: 0.0320 - val_loss: 0.0400
# Epoch 199/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0320 - val_loss: 0.0399
# Epoch 200/200
# 33/33 [==============================] - 16s 479ms/step - loss: 0.0320 - val_loss: 0.0399

# %%
modelDenoise.save(images_dir + 'modelDenoise_v3.h5')

# %%
yTest = modelDenoise.predict(xTest)
plotImages(xTest, yTest) # взглянем как отрабатывает шумоподавление на зашумленных картинках
