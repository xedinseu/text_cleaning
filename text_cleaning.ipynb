# %% [markdown]
# Отдельно хочу отметить, что до начала обучения (но после пилотной пробы сети) я предподготовил изображения - высота у многих изображений не соответствовала максимальной, и сверху и снизу таких изображений был добавлен серый фон чтобы добить высоту до 420 пикселей

# %%
# инфа по карте коллаба
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install -q gputil
# !pip install -q psutil
# !pip install -q humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
process = psutil.Process(os.getpid())
print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
print("GPU Model: ", gpu.name)
# Out:
#   Building wheel for gputil (setup.py) ... done
# Gen RAM Free: 12.8 GB  | Proc size: 118.0 MB
# GPU RAM Free: 16280MB | Used: 0MB | Util   0% | Total 16280MB
# GPU Model:  Tesla P100-PCIE-16GB

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, concatenate, Dense, Dropout, BatchNormalization, Conv2D, Conv2DTranspose, MaxPooling2D, Flatten,Reshape
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import utils
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.preprocessing import image
import tensorflow as tf

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import os
import time
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
images_dir = '/content/drive/MyDrive/Базы/text_cleaning/' # зададим имя папки в которой находятся данные
img_height = 424 # зададим высоту изображений
img_width = 544 # зададим ширину избражений

# %%
def plotImages(xTrain, pred, shape=(img_height, img_width)): # создадим функцию для вывода изображений как картинок
  n = 7  # количество картинок, которые хотим показать
  plt.figure(figsize=(28, 7)) # указываем размеры фигуры
  for i in range(n): # для каждой картинки из n(7)
      index = i
      # Показываем картинки из тестового набора
      ax = plt.subplot(2, n, i + 1) # выведем область рисования Axes
      plt.imshow(xTrain[index].reshape(shape)) # отрисуем правильные картинки в размере 112*80      
      plt.gray() # выведем в черно-белом цвете
      ax.get_xaxis().set_visible(False) # скрываем вывод координатной оси x
      ax.get_yaxis().set_visible(False) # скрываем вывод координатной оси y

      # Показываем восстановленные картинки
      ax = plt.subplot(2, n, i + 1 + n) # выведем область рисования Axes 
      plt.imshow(pred[index].reshape(shape)) # отрисуем обработанные сеткой картинки в размере 112*80     
      plt.gray() # выведем в черно-белом цвете
      ax.get_xaxis().set_visible(False) # скрываем вывод координатной оси x
      ax.get_yaxis().set_visible(False) # скрываем вывод координатной оси y
  plt.show()

# %%
# функция загрузки изображений, на вход принемает имя папки с изображениями, высоту и ширину к которой будут преобразованы загружаемые изображения
def load_images(images_dir, img_height, img_width): 
  list_images = [] # создаем пустой список в который будем загружать изображения
  for img in os.listdir(images_dir): # получим список изображений и для каждого изображения
  # добавим в список изображение в виде массива, с заданными размерами, в отенках серого
    list_images.append(image.img_to_array(image.load_img(os.path.join(images_dir, img), target_size=(img_height, img_width), color_mode='grayscale')))
  return np.array(list_images) # возвращаем numpy массив загруженных избражений

# %%
cur_time = time.time() 
xTrain = load_images(images_dir+'train_X', img_height, img_width) # загрузим избражения лиц
xTrain = xTrain/255 # отнормируем изображения от 0 до 1
yTrain = load_images(images_dir+'train_Y', img_height, img_width) # загрузим избражения лиц
yTrain = yTrain/255 # отнормируем изображения от 0 до 1
xTest = load_images(images_dir+'test', img_height, img_width) # загрузим избражения лиц
xTest = xTest/255 # отнормируем изображения от 0 до 1

# %%
xTrain.shape
# Out:
# (144, 424, 544, 1)

# %%
xTrain,xVal,yTrain,yVal = train_test_split(xTrain, yTrain, test_size=0.1)

# %%
def denoiseAutoencoder(): # объявляем функцию создания автокодировщика для подавления шума
    img_input = Input((img_height, img_width,1)) # задаём входные размеры

    # Добавляем четыре сверточных слоя, вместо MaxPooling используем strides
    #x1 = Conv2D(32, (3, 3), strides=2, activation='relu', padding='same')(img_input)
    #x1 = Conv2D(64, (3, 3), strides=2, activation='relu', padding='same')(x1)
    x1 = Conv2D(256, (4, 4), strides=2, activation='relu', padding='same')(img_input)
    #x1 = Conv2D(128, (4, 4), strides=2, activation='relu', padding='same')(x1)

    x1 = Conv2D(256, (4, 4), activation='relu', padding='same')(x1)
    #x1 = Conv2D(128, (4, 4), activation='relu', padding='same')(x1)
    #x1 = Conv2D(256, (4, 4), activation='relu', padding='same')(x1)

    #x1 = Conv2DTranspose(128, (4, 4), strides=2, padding='same')(x1) # разжимаем картинки из 7*5 до 14*10
    x1 = Conv2DTranspose(256, (4, 4), strides=2, padding='same')(x1) # разжимаем картинки из 14*10 до 28*20
    #x1 = Conv2DTranspose(64, (3, 3), strides=2, padding='same')(x1) # разжимаем картинки из 28*20 до 56*40
    #x1 = Conv2DTranspose(32, (3, 3), strides=2, padding='same')(x1) # разжимаем картинки из 56*40 до 112*80
    #x1 = Conv2D(32, (3, 3), activation='sigmoid', padding='same')(x1)

    #x2 = Conv2D(32, (2, 2), strides=2, activation='relu', padding='same')(img_input)
    #x2 = Conv2D(64, (2, 2), strides=2, activation='relu', padding='same')(x2)
    #x2 = Conv2D(256, (3, 3), strides=2, activation='relu', padding='same')(x1)
    x2 = Conv2D(128, (3, 3), strides=2, activation='relu', padding='same')(x1)

    x2 = Conv2D(256, (3, 3), activation='relu', padding='same')(x2)
    #x2 = Conv2D(128, (3, 3), activation='relu', padding='same')(x2)
    #x2 = Conv2D(256, (3, 3), activation='relu', padding='same')(x2)

    #x2 = Conv2DTranspose(128, (3, 3), strides=2, padding='same')(x2) # разжимаем картинки из 7*5 до 14*10
    x2 = Conv2DTranspose(256, (3, 3), strides=2, padding='same')(x2) # разжимаем картинки из 14*10 до 28*20
    #x2 = Conv2DTranspose(64, (2, 2), strides=2, padding='same')(x2) # разжимаем картинки из 28*20 до 56*40
    #x2 = Conv2DTranspose(32, (2, 2), strides=2, padding='same')(x2) # разжимаем картинки из 56*40 до 112*80
    #x2 = Conv2D(32, (3, 3), activation='sigmoid', padding='same')(x2)

    x = concatenate([x1,x2])
    x = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x) # и пропускаем через финальный слой двумерной свертки

    model = Model(img_input, x) # собрали модель с зашумленной картинкой на вход и с очищенной от шума на выход
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='mse') # компилируем модель также, с выбором оптимайзера и среднеквадратичной ошибки

    return model # функция вернет модель подавления шума

# %%
filename=images_dir + 'log.csv'
history_logger=tf.keras.callbacks.CSVLogger(filename, separator=",", append=False)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.75,patience=15, min_lr=0.000001)
modelDenoise = denoiseAutoencoder()
# Подаем на вход зашумленные картинки, а на выход правильные, исходные картинки, и обучаем
modelDenoise.fit(xTrain, yTrain, epochs=200, batch_size=4, validation_data = (xVal, yVal), callbacks=[reduce_lr,history_logger])
# Out:
# Epoch 1/200
# 33/33 [==============================] - 56s 972ms/step - loss: 0.0966 - val_loss: 0.0707
# Epoch 2/200
# 33/33 [==============================] - 26s 787ms/step - loss: 0.0719 - val_loss: 0.0684
# Epoch 3/200
# 33/33 [==============================] - 26s 791ms/step - loss: 0.0668 - val_loss: 0.0595
# Epoch 4/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0604 - val_loss: 0.0550
# Epoch 5/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0582 - val_loss: 0.0528
# Epoch 6/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0564 - val_loss: 0.0528
# Epoch 7/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0558 - val_loss: 0.0580
# Epoch 8/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0568 - val_loss: 0.0508
# Epoch 9/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0556 - val_loss: 0.0504
# Epoch 10/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0536 - val_loss: 0.0503
# Epoch 11/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0531 - val_loss: 0.0495
# Epoch 12/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0526 - val_loss: 0.0496
# Epoch 13/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0523 - val_loss: 0.0493
# Epoch 14/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0545 - val_loss: 0.0504
# Epoch 15/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0525 - val_loss: 0.0515
# Epoch 16/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0520 - val_loss: 0.0494
# Epoch 17/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0519 - val_loss: 0.0496
# Epoch 18/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0527 - val_loss: 0.0542
# Epoch 19/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0525 - val_loss: 0.0499
# Epoch 20/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0521 - val_loss: 0.0493
# Epoch 21/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0529 - val_loss: 0.0487
# Epoch 22/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0515 - val_loss: 0.0502
# Epoch 23/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0522 - val_loss: 0.0484
# Epoch 24/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0530 - val_loss: 0.0488
# Epoch 25/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0520 - val_loss: 0.0486
# Epoch 26/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0514 - val_loss: 0.0485
# Epoch 27/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0509 - val_loss: 0.0496
# Epoch 28/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0528 - val_loss: 0.0517
# Epoch 29/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0520 - val_loss: 0.0488
# Epoch 30/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0518 - val_loss: 0.0491
# Epoch 31/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0512 - val_loss: 0.0484
# Epoch 32/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0511 - val_loss: 0.0498
# Epoch 33/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0513 - val_loss: 0.0481
# Epoch 34/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0507 - val_loss: 0.0485
# Epoch 35/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0510 - val_loss: 0.0490
# Epoch 36/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0505 - val_loss: 0.0489
# Epoch 37/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0511 - val_loss: 0.0479
# Epoch 38/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0506 - val_loss: 0.0500
# Epoch 39/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0519 - val_loss: 0.0481
# Epoch 40/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0504 - val_loss: 0.0482
# Epoch 41/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0511 - val_loss: 0.0593
# Epoch 42/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0544 - val_loss: 0.0489
# Epoch 43/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0512 - val_loss: 0.0483
# Epoch 44/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0506 - val_loss: 0.0482
# Epoch 45/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0503 - val_loss: 0.0481
# Epoch 46/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0515 - val_loss: 0.0491
# Epoch 47/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0510 - val_loss: 0.0483
# Epoch 48/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0504 - val_loss: 0.0489
# Epoch 49/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0511 - val_loss: 0.0481
# Epoch 50/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0518 - val_loss: 0.0486
# Epoch 51/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0506 - val_loss: 0.0483
# Epoch 52/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0505 - val_loss: 0.0481
# Epoch 53/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0503 - val_loss: 0.0479
# Epoch 54/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0503 - val_loss: 0.0476
# Epoch 55/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0512 - val_loss: 0.0482
# Epoch 56/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0505 - val_loss: 0.0480
# Epoch 57/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0502 - val_loss: 0.0478
# Epoch 58/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0517 - val_loss: 0.0487
# Epoch 59/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0500 - val_loss: 0.0476
# Epoch 60/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0507 - val_loss: 0.0476
# Epoch 61/200
# 33/33 [==============================] - 26s 791ms/step - loss: 0.0505 - val_loss: 0.0476
# Epoch 62/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0501 - val_loss: 0.0474
# Epoch 63/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0502 - val_loss: 0.0477
# Epoch 64/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0502 - val_loss: 0.0477
# Epoch 65/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0505 - val_loss: 0.0478
# Epoch 66/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0500 - val_loss: 0.0475
# Epoch 67/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0500 - val_loss: 0.0474
# Epoch 68/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0504 - val_loss: 0.0475
# Epoch 69/200
# 33/33 [==============================] - 26s 791ms/step - loss: 0.0505 - val_loss: 0.0474
# Epoch 70/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0498 - val_loss: 0.0480
# Epoch 71/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0498 - val_loss: 0.0474
# Epoch 72/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0500 - val_loss: 0.0480
# Epoch 73/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0502 - val_loss: 0.0475
# Epoch 74/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0506 - val_loss: 0.0474
# Epoch 75/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0497 - val_loss: 0.0473
# Epoch 76/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0497 - val_loss: 0.0474
# Epoch 77/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0495 - val_loss: 0.0473
# Epoch 78/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0497 - val_loss: 0.0474
# Epoch 79/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0497 - val_loss: 0.0490
# Epoch 80/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0499 - val_loss: 0.0471
# Epoch 81/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0500 - val_loss: 0.0475
# Epoch 82/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0502 - val_loss: 0.0471
# Epoch 83/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0497 - val_loss: 0.0475
# Epoch 84/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0500 - val_loss: 0.0480
# Epoch 85/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0497 - val_loss: 0.0471
# Epoch 86/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0536 - val_loss: 0.0517
# Epoch 87/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0514 - val_loss: 0.0482
# Epoch 88/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0504 - val_loss: 0.0476
# Epoch 89/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0498 - val_loss: 0.0486
# Epoch 90/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0501 - val_loss: 0.0485
# Epoch 91/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0499 - val_loss: 0.0480
# Epoch 92/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0496 - val_loss: 0.0480
# Epoch 93/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0504 - val_loss: 0.0471
# Epoch 94/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0496 - val_loss: 0.0469
# Epoch 95/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0499 - val_loss: 0.0471
# Epoch 96/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0496 - val_loss: 0.0474
# Epoch 97/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0502 - val_loss: 0.0474
# Epoch 98/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0508 - val_loss: 0.0473
# Epoch 99/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0498 - val_loss: 0.0472
# Epoch 100/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0495 - val_loss: 0.0471
# Epoch 101/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0499 - val_loss: 0.0473
# Epoch 102/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0497 - val_loss: 0.0473
# Epoch 103/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0494 - val_loss: 0.0477
# Epoch 104/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0493 - val_loss: 0.0474
# Epoch 105/200
# 33/33 [==============================] - 26s 791ms/step - loss: 0.0500 - val_loss: 0.0474
# Epoch 106/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0498 - val_loss: 0.0472
# Epoch 107/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0494 - val_loss: 0.0473
# Epoch 108/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0496 - val_loss: 0.0481
# Epoch 109/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0497 - val_loss: 0.0473
# Epoch 110/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0493 - val_loss: 0.0471
# Epoch 111/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0493 - val_loss: 0.0469
# Epoch 112/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0493 - val_loss: 0.0471
# Epoch 113/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0493 - val_loss: 0.0472
# Epoch 114/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0494 - val_loss: 0.0479
# Epoch 115/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0492 - val_loss: 0.0468
# Epoch 116/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0493 - val_loss: 0.0473
# Epoch 117/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0497 - val_loss: 0.0472
# Epoch 118/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0494 - val_loss: 0.0468
# Epoch 119/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0492 - val_loss: 0.0470
# Epoch 120/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0495 - val_loss: 0.0469
# Epoch 121/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0490 - val_loss: 0.0470
# Epoch 122/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0490 - val_loss: 0.0469
# Epoch 123/200
# 33/33 [==============================] - 26s 794ms/step - loss: 0.0495 - val_loss: 0.0478
# Epoch 124/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0517 - val_loss: 0.0472
# Epoch 125/200
# 33/33 [==============================] - 26s 791ms/step - loss: 0.0494 - val_loss: 0.0471
# Epoch 126/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0494 - val_loss: 0.0474
# Epoch 127/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0493 - val_loss: 0.0476
# Epoch 128/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0494 - val_loss: 0.0475
# Epoch 129/200
# 33/33 [==============================] - 26s 791ms/step - loss: 0.0493 - val_loss: 0.0473
# Epoch 130/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0491 - val_loss: 0.0471
# Epoch 131/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0490 - val_loss: 0.0469
# Epoch 132/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0490 - val_loss: 0.0474
# Epoch 133/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0491 - val_loss: 0.0466
# Epoch 134/200
# 33/33 [==============================] - 26s 791ms/step - loss: 0.0490 - val_loss: 0.0467
# Epoch 135/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0489 - val_loss: 0.0470
# Epoch 136/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0492 - val_loss: 0.0468
# Epoch 137/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0492 - val_loss: 0.0469
# Epoch 138/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0492 - val_loss: 0.0473
# Epoch 139/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0489 - val_loss: 0.0466
# Epoch 140/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0489 - val_loss: 0.0471
# Epoch 141/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0490 - val_loss: 0.0469
# Epoch 142/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0491 - val_loss: 0.0469
# Epoch 143/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0489 - val_loss: 0.0468
# Epoch 144/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0497 - val_loss: 0.0478
# Epoch 145/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0492 - val_loss: 0.0467
# Epoch 146/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0490 - val_loss: 0.0468
# Epoch 147/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0489 - val_loss: 0.0469
# Epoch 148/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0490 - val_loss: 0.0468
# Epoch 149/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0491 - val_loss: 0.0475
# Epoch 150/200
# 33/33 [==============================] - 26s 791ms/step - loss: 0.0491 - val_loss: 0.0471
# Epoch 151/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0489 - val_loss: 0.0468
# Epoch 152/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0488 - val_loss: 0.0467
# Epoch 153/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0489 - val_loss: 0.0466
# Epoch 154/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0488 - val_loss: 0.0468
# Epoch 155/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0487 - val_loss: 0.0468
# Epoch 156/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0488 - val_loss: 0.0470
# Epoch 157/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0487 - val_loss: 0.0467
# Epoch 158/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0486 - val_loss: 0.0465
# Epoch 159/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0489 - val_loss: 0.0471
# Epoch 160/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0488 - val_loss: 0.0465
# Epoch 161/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0488 - val_loss: 0.0465
# Epoch 162/200
# 33/33 [==============================] - 26s 791ms/step - loss: 0.0487 - val_loss: 0.0468
# Epoch 163/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0486 - val_loss: 0.0468
# Epoch 164/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0489 - val_loss: 0.0465
# Epoch 165/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0488 - val_loss: 0.0471
# Epoch 166/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0487 - val_loss: 0.0467
# Epoch 167/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0486 - val_loss: 0.0466
# Epoch 168/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0487 - val_loss: 0.0471
# Epoch 169/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0487 - val_loss: 0.0465
# Epoch 170/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0490 - val_loss: 0.0468
# Epoch 171/200
# 33/33 [==============================] - 26s 791ms/step - loss: 0.0487 - val_loss: 0.0466
# Epoch 172/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0488 - val_loss: 0.0467
# Epoch 173/200
# 33/33 [==============================] - 26s 791ms/step - loss: 0.0487 - val_loss: 0.0466
# Epoch 174/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0486 - val_loss: 0.0468
# Epoch 175/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0487 - val_loss: 0.0465
# Epoch 176/200
# 33/33 [==============================] - 26s 791ms/step - loss: 0.0485 - val_loss: 0.0468
# Epoch 177/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0485 - val_loss: 0.0466
# Epoch 178/200
# 33/33 [==============================] - 26s 791ms/step - loss: 0.0487 - val_loss: 0.0465
# Epoch 179/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0486 - val_loss: 0.0465
# Epoch 180/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0485 - val_loss: 0.0465
# Epoch 181/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0486 - val_loss: 0.0465
# Epoch 182/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0485 - val_loss: 0.0466
# Epoch 183/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0485 - val_loss: 0.0466
# Epoch 184/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0485 - val_loss: 0.0465
# Epoch 185/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0485 - val_loss: 0.0467
# Epoch 186/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0485 - val_loss: 0.0464
# Epoch 187/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0486 - val_loss: 0.0465
# Epoch 188/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0484 - val_loss: 0.0466
# Epoch 189/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0486 - val_loss: 0.0468
# Epoch 190/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0486 - val_loss: 0.0465
# Epoch 191/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0485 - val_loss: 0.0466
# Epoch 192/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0484 - val_loss: 0.0466
# Epoch 193/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0485 - val_loss: 0.0465
# Epoch 194/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0484 - val_loss: 0.0465
# Epoch 195/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0485 - val_loss: 0.0467
# Epoch 196/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0485 - val_loss: 0.0464
# Epoch 197/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0484 - val_loss: 0.0466
# Epoch 198/200
# 33/33 [==============================] - 26s 791ms/step - loss: 0.0485 - val_loss: 0.0465
# Epoch 199/200
# 33/33 [==============================] - 26s 793ms/step - loss: 0.0484 - val_loss: 0.0463
# Epoch 200/200
# 33/33 [==============================] - 26s 792ms/step - loss: 0.0503 - val_loss: 0.0471

# %%
modelDenoise.save(images_dir + 'modelDenoise.h5')

# %%
yTest = modelDenoise.predict(xTest)
plotImages(xTest, yTest) # взглянем как отрабатывает шумоподавление на зашумленных картинках

# %%
modelDenoise.fit(xTrain, yTrain, epochs=100, batch_size=8, validation_data = (xVal, yVal), callbacks=[reduce_lr,history_logger])
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-13-8ac0246b2249> in <module>()
# ----> 1 modelDenoise.fit(xTrain, yTrain, epochs=100, batch_size=8, validation_data = (xVal, yVal), callbacks=[reduce_lr,history_logger])
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
# -> 3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#    3042   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1962       # No tape is watching; skip to running the function.
#    1963       return self._build_call_outputs(self._inference_function.call(
# -> 1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#    1966         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[8,512,424,544] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node gradient_tape/model/conv2d_4/Conv2D/Conv2DBackpropInput (defined at <ipython-input-10-f9c7c688bb08>:7) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_1032]
#
# Function call stack:
# train_function

# %%
yTest = modelDenoise.predict(xTest)
plotImages(xTest, yTest) # взглянем как отрабатывает шумоподавление на зашумленных картинках

# %%
modelDenoise.save(images_dir + 'modelDenoise.h5')
